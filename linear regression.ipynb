# %%
# 필요한 라이브러리 불러오기

import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.optimizers import SGD, Adam

import numpy as np

print(tf.__version__)
# Out:
# 2.0.0

# %%
# Tensorflow 2.x 에서 바뀐점

# 과거에는 직접 수식을 적어서 계산했지만
# Tensorflow 2.x 버전부터는 Keras API를 활용하여 모델을 구축한다.
# 계산 과정은 똑같지만 모델 속에 있는 층에서 알아서 계산되는듯 하다.

# %%
# linear regression : 선형 학습모델을 만들어서 미지의 데이터의 결과를 에측해보는 작업
# 목표 : 손실함수를 작게 만들어 믿을 수 있을만한 모델을 만든느것이다.


"""
Linear Regression Flow Chart

데이터 생성 --> 모델 구축 --> 모델 컴파일 --> 모델 학습 --> 모델 평가 및 예측

"""
# Out:
# '\nLinear Regression Flow Chart\n\n데이터 생성 --> 모델 구축 --> 모델 컴파일 --> 모델 학습 --> 모델 평가 및 예측\n\n'

# %%
# 데이터 생성

# 학습할 데이터 ( 간단한 예제이므로 트레이닝 데이터만을 만들었다. ) 
x_train = np.array([ [1,2,0], [5,4,3], [1,2,-1] ,[3,1,0], [2,4,2],
                   [4,1,2], [-1,3,2], [4,3,3] ,[0,2,6], [2,2,1],
                   [1,-2,-2], [0,1,3], [1,1,3] ,[0,1,4], [2,3,3] ])

y_train = np.array([ -4, -4, -6, 3, -4,
                   9, -7, 5, 6, 0,
                   4, 3, 5, 5, 1])

print('x_train.shape = ', x_train.shape, ', y_train.shape = ', y_train.shape)
# Out:
# x_train.shape =  (15, 3) , y_train.shape =  (15,)

# %%
# 모델 구축

model = Sequential()

# 입력 데이터의 크기와 활성화 함수 이름
model.add(Dense(1, input_shape=(3,), activation='linear'))

# %%
# 모델 컴파일

# 학습 알고리즘(SGD)과 학습률, 손실함수 지정
model.compile(optimizer=SGD(learning_rate=1e-2), loss='mse')

# 학습 전에 요약한 내용을 한번 본다. ( 입력층에서 오는 가중치 3개와 bias 1개)
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 1)                 4
# ...
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 학습

hist = model.fit(x_train, y_train, epochs=1000)
# Out:
# Train on 15 samples
# Epoch 1/1000
# 15/15 [==============================] - 0s 20ms/sample - loss: 19.8394
# Epoch 2/1000
# 15/15 [==============================] - 0s 67us/sample - loss: 17.7689
# Epoch 3/1000
# 15/15 [==============================] - 0s 67us/sample - loss: 16.4260
# Epoch 4/1000
# 15/15 [==============================] - 0s 133us/sample - loss: 15.4589
# Epoch 5/1000
# 15/15 [==============================] - 0s 67us/sample - loss: 14.6929
# Epoch 6/1000
# 15/15 [==============================] - 0s 133us/sample - loss: 14.0408
# Epoch 7/1000
# 15/15 [==============================] - 0s 134us/sample - loss: 13.4589
# Epoch 8/1000
# 15/15 [==============================] - 0s 66us/sample - loss: 12.9246
# Epoch 9/1000
# 15/15 [==============================] - 0s 67us/sample - loss: 12.4262
# Epoch 10/1000
# 15/15 [==============================] - 0s 67us/sample - loss: 11.9572
# Epoch 11/1000
# ...

# %%
# 모델 평가 및 예측

test_data = [ [5,5,0], [2,3,1], [-1,0,-1], [10,5,2], [4,-1,-2]]

# 이건 정답
ret_val = [ 2*data[0] -3*data[1] + 2*data[2] for data in test_data]

prediction_val = model.predict(np.array(test_data))

print(prediction_val)
print('========================')
print(ret_val)
# Out:
# [[-8.232289 ]
#  [-3.9877949]
#  [-2.1857815]
#  [ 2.7164848]
#  [ 6.3205123]]
# ...
# [-5, -3, -4, 9, 7]

# %%
print(model.input)
print(model.output)
print(model.weights)
# Out:
# Tensor("dense_1_input:0", shape=(None, 3), dtype=float32)
# Tensor("dense_1/Identity:0", shape=(None, 1), dtype=float32)
# [<tf.Variable 'dense_1/kernel:0' shape=(3, 1) dtype=float32, numpy=
# array([[ 1.4240316],
#        [-3.3008847],
#        [ 1.914525 ]], dtype=float32)>, <tf.Variable 'dense_1/bias:0' shape=(1,) dtype=float32, numpy=array([1.1522042], dtype=float32)>]

# %%
# 모델 가중치, 바이어스와 손실함수 추세를 확인해보자.

import matplotlib.pyplot as plt

plt.title('Losee Trend')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.grid()

plt.plot(hist.history['loss'], label='train loss')
plt.legend(loc='best')

plt.show()
